# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjal-102/Pranjal-102/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
n = int(input("Enter the number of items: "))
items = []
for i in range(n):
    vi = int(input(f"Enter the value of item {i+1}: "))
    wi = int(input(f"Enter the weight of item {i+1}: "))
    ratio = vi/wi
    items.append((ratio, vi, wi))
items.sort(reverse=True)
W = int(input("Enter the maximum capacity of the knapsack: "))
print("items after sorting on the basis of vi/wi ratio in descending order :",items)
profit=0.0
remaining_capacity=W
for i in range(n):
  o=items[i]
  if remaining_capacity==0:
     break
  if o[2]<=remaining_capacity:
    profit+=vi
    remaining_capacity-=wi
  else:
    profit+=o[0]*remaining_capacity
    remaining_capacity=0
    print(f"Took fraction of item (value: {vi}, weight: {wi}, fraction: {ratio}). Remaining capacity: {remaining_capacity}. Current total value: {profit}")

print(f"\nMaximum total value for knapsack: {profit}")
# Out:
# Enter the number of items: 4
# Enter the value of item 1: 23
# Enter the weight of item 1: 2
# Enter the value of item 2: 1
# Enter the weight of item 2: 2
# Enter the value of item 3: 3
# Enter the weight of item 3: 56
# Enter the value of item 4: 754
# Enter the weight of item 4: 663
# Enter the maximum capacity of the knapsack: 100
# items after sorting on the basis of vi/wi ratio in descending order : [(11.5, 23, 2), (1.1372549019607843, 754, 663), (0.5, 1, 2), (0.05357142857142857, 3, 56)]
# Took fraction of item (value: 754, weight: 663, fraction: 1.1372549019607843). Remaining capacity: 0. Current total value: 113.72549019607845
#
# Maximum total value for knapsack: 113.72549019607845

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
import heapq

class Node:
    def __init__(self, char, freq):
        self.char = char
        self.freq = freq
        self.left = None
        self.right = None

    def __lt__(self, other):
        return self.freq < other.freq


def build_tree(freq):
    heap = []
    for c in freq:
        heapq.heappush(heap, Node(c, freq[c]))

    while len(heap) > 1:
        l = heapq.heappop(heap)
        r = heapq.heappop(heap)

        n = Node(None, l.freq + r.freq)
        n.left = l
        n.right = r

        heapq.heappush(heap, n)

    return heap[0]


def get_codes(root, code="", d=None):
    if d is None:
        d = {}

    if root is None:
        return

    if root.char is not None:
        d[root.char] = code
        return d

    get_codes(root.left, code + "0", d)
    get_codes(root.right, code + "1", d)

    return d


def encode(text, codes):
    return "".join(codes[c] for c in text)


def decode(enc, root):
    res = ""
    cur = root

    for b in enc:
        cur = cur.left if b == "0" else cur.right

        if cur.char is not None:
            res += cur.char
            cur = root

    return res


def main():
    text = input("Enter text: ")
    freq = {}
    for c in text:
        freq[c] = freq.get(c, 0) + 1
    root = build_tree(freq)
    codes = get_codes(root)
    print("\nHuffman Codes:")
    print(codes)
    enc = encode(text, codes)
    print("\nEncoded string:")
    print(enc)
    dec = decode(enc, root)
    print("\nDecoded string:")
    print(dec)


if __name__ == "__main__":
    main()
